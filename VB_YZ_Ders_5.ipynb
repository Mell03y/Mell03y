# %% [markdown]
# <a href="https://colab.research.google.com/github/Mell03y/Mell03y/blob/main/VB_YZ_Ders_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Series **

# %%
notlar = {"Gürhan": 50, "Ayşe": 60, "Leyla":70}

# %%
notlar
# Out:
# {'Gürhan': 50, 'Ayşe': 60, 'Leyla': 70}

# %%
pd.Series(notlar)
# Out:
# Gürhan    50
# Ayşe      60
# Leyla     70
# dtype: int64

# %%
numpy_array = np.array([50,60,70,80])

# %%
numpy_array
# Out:
# array([50, 60, 70, 80])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# dtype: int64

# %% [markdown]
# **Data Frame**

# %%
data = np.random.randint(10, size=(4,4))

# %%
data
# Out:
# array([[9, 5, 5, 4],
#        [7, 7, 4, 1],
#        [4, 9, 2, 3],
#        [1, 9, 9, 2]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#    0  1  2  3
# 0  9  5  5  4
# 1  7  7  4  1
# 2  4  9  2  3
# 3  1  9  9  2

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame[0]
# Out:
# 0    9
# 1    7
# 2    4
# 3    1
# Name: 0, dtype: int64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
data_frame
# Out:
#    0  1  2  3
# 0  9  5  5  4
# 1  7  7  4  1
# 2  4  9  2  3
# 3  1  9  9  2

# %%
new_df = pd.DataFrame(data, index=["Gürhan","Ayşe","Elif","Melike"], columns = ["Ders1","Ders2", "Ders3","Ders4"])

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      9      5      5      4
# Ayşe        7      7      4      1
# Elif        4      9      2      3
# Melike      1      9      9      2

# %%
new_df['Ders1']
# Out:
# Gürhan    9
# Ayşe      7
# Elif      4
# Melike    1
# Name: Ders1, dtype: int64

# %%
new_df['Ders2']
# Out:
# Gürhan    5
# Ayşe      7
# Elif      9
# Melike    9
# Name: Ders2, dtype: int64

# %%
new_df['Ders3']
# Out:
# Gürhan    5
# Ayşe      4
# Elif      2
# Melike    9
# Name: Ders3, dtype: int64

# %%
# new_df['Gürhan']. - satır seçerken hata verir.

# %%
new_df.loc["Gürhan"]
# Out:
# Ders1    9
# Ders2    5
# Ders3    5
# Ders4    4
# Name: Gürhan, dtype: int64

# %%
new_df.loc["Elif"]
# Out:
# Ders1    4
# Ders2    9
# Ders3    2
# Ders4    3
# Name: Elif, dtype: int64

# %%
new_df.iloc[0]
# Out:
# Ders1    9
# Ders2    5
# Ders3    5
# Ders4    4
# Name: Gürhan, dtype: int64

# %%
new_df.iloc[1]
# Out:
# Ders1    7
# Ders2    7
# Ders3    4
# Ders4    1
# Name: Ayşe, dtype: int64

# %%
new_df.iloc[3]
# Out:
# Ders1    1
# Ders2    9
# Ders3    9
# Ders4    2
# Name: Melike, dtype: int64

# %%
new_df.loc[["Ayşe","Elif"]]
# Out:
#       Ders1  Ders2  Ders3  Ders4
# Ayşe      7      7      4      1
# Elif      4      9      2      3

# %%
new_df.loc["Gürhan":"Elif"]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      9      5      5      4
# Ayşe        7      7      4      1
# Elif        4      9      2      3

# %%
new_df.iloc[0:2]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      9      5      5      4
# Ayşe        7      7      4      1

# %%
new_df.iloc[0:3]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      9      5      5      4
# Ayşe        7      7      4      1
# Elif        4      9      2      3

# %%
new_df.iloc[0:3,1:3]
# Out:
#         Ders2  Ders3
# Gürhan      5      5
# Ayşe        7      4
# Elif        9      2

# %% [markdown]
# **Data Manipülasyon - Satır Sütun Ekleme Çıkarma **

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      9      5      5      4
# Ayşe        7      7      4      1
# Elif        4      9      2      3
# Melike      1      9      9      2

# %%
new_df["Ders5"] = 8

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5
# Gürhan      9      5      5      4      8
# Ayşe        7      7      4      1      8
# Elif        4      9      2      3      8
# Melike      1      9      9      2      8

# %%
new_df["Ders5"] = [3,4,5,6]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5
# Gürhan      9      5      5      4      3
# Ayşe        7      7      4      1      4
# Elif        4      9      2      3      5
# Melike      1      9      9      2      6

# %%
new_df["Ders6"] = [2,4,5,1]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      9      5      5      4      3      2
# Ayşe        7      7      4      1      4      4
# Elif        4      9      2      3      5      5
# Melike      1      9      9      2      6      1

# %%
new_df["Ders7"] = new_df["Ders3"] * 3

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6  Ders7
# Gürhan      9      5      5      4      3      2     15
# Ayşe        7      7      4      1      4      4     12
# Elif        4      9      2      3      5      5      6
# Melike      1      9      9      2      6      1     27

# %%
new_df.drop("Ders7", axis=1) # Sütun silme axis parametresi 1 verildi. Sütun bazlı işlem için.
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      9      5      5      4      3      2
# Ayşe        7      7      4      1      4      4
# Elif        4      9      2      3      5      5
# Melike      1      9      9      2      6      1

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6  Ders7
# Gürhan      9      5      5      4      3      2     15
# Ayşe        7      7      4      1      4      4     12
# Elif        4      9      2      3      5      5      6
# Melike      1      9      9      2      6      1     27

# %%
new_df_2 = new_df.drop("Ders7", axis=1) # Sütun silme işlemini kaydetmek için yeni değişkene atadık.

# %%
new_df_2
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      9      5      5      4      3      2
# Ayşe        7      7      4      1      4      4
# Elif        4      9      2      3      5      5
# Melike      1      9      9      2      6      1

# %%
new_df.drop("Ders6", axis=1 , inplace=True) #inplace parametresi TRUE değeri atandığında dataframe içinde o işlemi yapıyor ve kaydediyor. Yoksa yukarıda yapıldığı gibi bir değişkene atanmalı.

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      9      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27

# %%
new_df.drop("Melike", axis=0)
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      9      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      9      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27

# %%
new_df.loc["Mehmet"] = 15

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      9      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27
# Mehmet     15     15     15     15     15     15

# %%
new_df.loc["Ahmet"] = [3,5,7,8,9,3]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      9      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27
# Mehmet     15     15     15     15     15     15
# Ahmet       3      5      7      8      9      3

# %%
new_df.iloc[0,0:1] = 8

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27
# Mehmet     15     15     15     15     15     15
# Ahmet       3      5      7      8      9      3

# %%
new_df.loc["Ahmet","Ders1"] = 5

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27
# Mehmet     15     15     15     15     15     15
# Ahmet       5      5      7      8      9      3

# %%
new_df.loc["Mehmet","Ders1"] = 6

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Elif        4      9      2      3      5      6
# Melike      1      9      9      2      6     27
# Mehmet      6     15     15     15     15     15
# Ahmet       5      5      7      8      9      3

# %% [markdown]
# **Filtrelemeler**

# %%
bool_frame = new_df > 5

# %%
bool_frame
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan   True  False  False  False  False   True
# Ayşe     True   True  False  False  False   True
# Elif    False   True  False  False  False   True
# Melike  False   True   True  False   True   True
# Mehmet   True   True   True   True   True   True
# Ahmet   False  False   True   True   True  False

# %%
new_df[new_df > 5]
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan    8.0    NaN    NaN    NaN    NaN   15.0
# Ayşe      7.0    7.0    NaN    NaN    NaN   12.0
# Elif      NaN    9.0    NaN    NaN    NaN    6.0
# Melike    NaN    9.0    9.0    NaN    6.0   27.0
# Mehmet    6.0   15.0   15.0   15.0   15.0   15.0
# Ahmet     NaN    NaN    7.0    8.0    9.0    NaN

# %%
new_df[new_df["Ders1"]>5]
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      5      5      4      3     15
# Ayşe        7      7      4      1      4     12
# Mehmet      6     15     15     15     15     15

# %% [markdown]
# **.csv dosya okuma, gerçek dataları içeri alma. **

# %%
notlar_df = pd.read_csv("/content/ECS_Veri_Bilimi_Yapay_Zeka_notlar_eksik_new.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1244/2352282083.py in <cell line: 0>()
# ----> 1 notlar_df = pd.read_csv("/content/ECS_Veri_Bilimi_Yapay_Zeka_notlar_eksik_new.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ECS_Veri_Bilimi_Yapay_Zeka_notlar_eksik_new.csv'

# %%
notlar_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1244/729505142.py in <cell line: 0>()
# ----> 1 notlar_df
#
# NameError: name 'notlar_df' is not defined

# %%
notlar_df.head() # data frame'in ilk 5 verisini getirir.

# %%
notlar_df.tail() # data frame'in son 5 verisini getirir.

# %%
notlar_df.describe() # dataframe hakkında temel istatistiksel verileri veriyor.

# %%
notlar_df.shape # satır ve sütun sayıları

# %%
notlar_df.columns

# %%
notlar_df.info()# Dataframe Sütunları ile ilgili genel bilgi.

# %%
notlar_df.isna() # boş değerler ile ilgili boşta true

# %%
notlar_df["sinav1"].isna() # boş değerler ile ilgili sütun seçtik. boşsa true

# %%
notlar_df

# %%
notlar_df.drop("proje", axis=1)

# %%
notlar_df

# %%
notlar_df.fillna(10) #tüm boşlukları "10 sayısı ile doldur." neden 10 çünkü o değeri atadık bir önemi yok. 20 30 50 olabilir.

# %%
notlar_df

# %%
notlar_df.mean() # Genel Sütun ortalamaları

# %%
notlar_df.fillna(notlar_df.mean()) #Tüm boşlukları sütun ortalamaları ile doldur.

# %%
notlar_df.max() #sütun maximum değerleri

# %%
notlar_df.min() #sütun minumum değerleri

# %%
notlar_df

# %%
notlar_df["sinav1"] = notlar_df["sinav1"].fillna(notlar_df["sinav1"].mean() ) # tek bir sütunun eksik verilerini doldurma.

# %%
notlar_df

# %% [markdown]
# **CONCAT Kavramı - MERGE Kavramı**

# %%
df = pd.read_csv("/content/5. Ders - concat_data1.csv")

# %%
df

# %%
df2 = pd.read_csv("/content/5. Ders - concat_data2.csv")

# %%
df2

# %%
df_concat = pd.concat([df,df2], ignore_index=True)

# %%
df_concat

# %%
df3 = pd.read_csv("/content/5. Ders - merge_data1.csv")

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1244/1715873167.py in <cell line: 0>()
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
df4 = pd.read_csv("/content/5. Ders - merge_data2.csv")

# %%
df4

# %%
df_merge = pd.merge(df3, df4, on="Employee_ID", how="inner")

# %%
df_merge

# %%
df_merge2 = pd.merge(df3, df4, on="Employee_ID", how="outer")

# %%
df_merge2

# %%
df_merge3 = pd.merge(df3, df4, on="Employee_ID", how="left")

# %%
df_merge3

# %%
df_merge4 = pd.merge(df3, df4, on="Employee_ID", how="right")

# %%
df_merge4
